# %% [markdown]
# # Univariate, Bivariate and Multivariate Data Visualization

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv('employee.csv')
print(data.shape)
data.tail()
# Out:
# (1470, 35)
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# 1465                23          2        Medical              1
# 1466                 6          1        Medical              1
# 1467                 4          3  Life Sciences              1
# 1468                 2          3        Medical              1
# 1469                 8          3        Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %% [markdown]
# ## Univariate Analysis

# %%
sns.distplot(data['Age'])
# Out:
# C:\Users\claim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %%
sns.countplot(data.BusinessTravel) # Categorical Variable
# Out:
# C:\Users\claim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BusinessTravel', ylabel='count'>

# %% [markdown]
# ## Bivariate Analysis

# %%
sns.barplot(data['Department'], data['MonthlyIncome']) # Categorical vs Numerical
# Out:
# C:\Users\claim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Department', ylabel='MonthlyIncome'>

# %% [markdown]
# Employees in Sales have a better average salary

# %%
sns.scatterplot(data['Age'], data['MonthlyIncome'])
# Out:
# C:\Users\claim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age', ylabel='MonthlyIncome'>

# %% [markdown]
# Younger Employees tend to have less salary
#
#
# ## Multivariate Analysis

# %%
plt.rcParams['figure.figsize'] = (18, 8)
sns.heatmap(data.corr(), annot = True, fmt = '0.2f')
plt.show()

# %% [markdown]
# If 2 columns are highly correlated, it means they are related to each other.

# %%
sns.barplot(data['Department'], data['MonthlyIncome'], data['Attrition'])
# Out:
# C:\Users\claim\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y, hue. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Department', ylabel='MonthlyIncome'>

# %% [markdown]
# This shows us how many employees get or don't get attrited in each department (most in HR)
